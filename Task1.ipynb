# %% [markdown]
# ## Importing Required libaries for Data Cleaning and Processing

# %%
# importing essential libraries for data analysis
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading the Dataset
# ## syntax:dataframe_name=pd.read_file_type(r"file path")

# %%
# Loading the Dataset by declaring a dataframe name
netflix_shows=pd.read_csv(r"C:\Users\Madhu\Documents\Internship Data Sets\Netfix movies and Tv Shows\netflix_titles.csv")
netflix_shows
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### SHAPE
# ## Returns number of rows and columns in the dataframe
# ## syntax:dataframe.shape

# %%
# SHAPE
netflix_shows.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## Index
# ## Returns the index start ,stop,and step values
# ## Syntax:dataframe.index

# %%
# INDEX
netflix_shows.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %% [markdown]
# ## Head
# ## Returns top 5 rows in a dataframe
# ## syntax:dataframe.head()

# %%
# HEAD
netflix_shows.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Tail
# ## Returns bottom 5 rows in a dataframe
# ## syntax:dataframe.tail()

# %%
# TAIL
netflix_shows.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ### Cloumns
# ## Returns the names of the columns
# ## syntax:dataframe.columns

# %%
# Columns
netflix_shows.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ## INFO/Overview-Returns summary of the dataframe
# ## Number of rows,Number of Columns,Datatypes of columns,Column names etc..
# ## Syntax:dataframe.info()

# %%
# INFO
netflix_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## DESCRIBE-Generates discriptive stats of the dataframe
# ## Including count,mean,standard deviation,minimum,maximum,25quartile,median or 50th quartile, 75th quartile
# ## Performs only on numerical data
# ## syntax:dataframe.describe()

# %%
# DESCRIBE
netflix_shows.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Describing for categorical data
netflix_shows.describe(include='O')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# ## nunique
# ## Returns the count of unique values in the labels or columns
# ## syntax:dataframe.nunique()

# %%
# NUNIQUE
netflix_shows.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# ## dtypes
# ## Returns the data types of columns
# ## syntax:dataframe.dtypes

# %%
# data types
netflix_shows.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ## ISNULL
# ## Returns the bollean output
# ## syntax:dataframe.isnull()

# %%
# ISNULL
netflix_shows.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# ISNULL
# Finding the sum of null values in the dataframe 
netflix_shows.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## HANDLING MISSING VALUES
# ## IMPUTATION METHOD
# ## syntax:dataframe.fillna(value="any value",inplace=True)

# %%
# filling the missing values in the director column
netflix_shows['director'].fillna(value="Rajiv Chilaka",inplace=True)

# %%
# filling the missing values in cast column 
netflix_shows['cast'].fillna(value="David Attenborough",inplace=True)

# %%
# filling the missing values in country column
netflix_shows['country'].fillna(value="United States",inplace=True)

# %%
# filling the missing values in date_added column
netflix_shows['date_added'].fillna(value="January 1, 2020",inplace=True)

# %%
# filling the missing values in the rating column
netflix_shows['rating'].fillna(value="TV-MA",inplace=True)

# %% [markdown]
# ## Note:In the above i have replaced with the specific values because these are the most or top occuring values so i used them to replace the null values

# %%
# rechecking the null values
netflix_shows.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## Duplicate values/records
# ## drop_duplicates
# ## It is used to drop the duplicate records in the dataframe
# ## syntax:dataframe.dropduplicates()
# ## Note:If the complete row records matches with the other row then it is called as duplicate row this values/records only deleted.

# %%
# Dropping the duplicate records in the dataframe
netflix_shows.drop_duplicates()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Rajiv Chilaka
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4         s5  TV Show           Kota Factory    Rajiv Chilaka
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    Rajiv Chilaka
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                    David Attenborough  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Converting to datatime data type
# ## syntax:dataframe['date_column']=pd.to_datetime(dataframe['date_column'])

# %%
# converting date_added to date time format
netflix_shows['date_added']=pd.to_datetime(netflix_shows['date_added'],format='%dd-%mm-%yy')
netflix_shows['date_added']
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
# converting date column to date time data type
netflix_shows['date_added']=pd.to_datetime(netflix_shows['date_added'])

# %%
# converting release_year to date time data type
netflix_shows['release_year']=pd.to_datetime(netflix_shows['release_year'],format='%Y')

# %%
netflix_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   datetime64[ns]
#  7   release_year  8807 non-null   datetime64[ns]
#  8   rating        8807 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 825.8+ KB
